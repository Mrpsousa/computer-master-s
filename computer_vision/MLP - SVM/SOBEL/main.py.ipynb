# %%
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
import h5py
import numpy as np
from sklearn import svm
from sklearn.metrics import confusion_matrix

# 0 - cat
# 1 - dog

labels = h5py.File('labels.h5', 'r')

x_test = np.load('test.npz')['arr_0']
x_train = np.load('train.npz')['arr_0']
y_train = np.array(labels['label'])

labels.close()

# svm.SVC(*, C=1.0, kernel='rbf', degree=3, gamma='scale', 
#         coef0=0.0, shrinking=True, probability=False, tol=0.001, 
#         cache_size=200, class_weight=None, verbose=False, 
#         max_iter=- 1, decision_function_shape='ovr', 
#         break_ties=False, random_state=None)[source]

clf = svm.SVC(C=1,kernel="linear",  verbose=True).fit(x_train,y_train)
svm_predictions = clf.predict(x_test)
print("foi")

count = 0
um_cat = 0
zero_cat = 0
um_dog = 0
zero_dog = 0

for line in svm_predictions:
    if count < 5000 and line == 1:
        um_cat += 1
    elif count < 5000 and line == 0:
        zero_cat += 1
    elif count >= 5000 and line == 1:
        um_dog += 1
    elif count >= 5000 and line == 0:
        zero_dog += 1
    print(count, line )
    count += 1

print(f'cat fail : {um_cat}')
print(f'cat success: {zero_cat}')
print(f'dog fail: {zero_dog}')
print(f'dog success: {um_dog}')

# accuracy = clf.score(x_test, labels)
 
# print(accuracy)
# # creating a confusion matrix
# cm = confusion_matrix(y_test, svm_predictions) # usar no MLP tbm
# print(cm)
#-----------------------------------------------------------------------------------------

# clf = MLPClassifier(activation = 'tanh', alpha=0.001,
#                     random_state=1,
#                     verbose = True, max_iter=10).fit(x_train, y_train)


# print ('Predicting...')
# count = 1 
# um_cat = 0
# zero_cat = 0
# um_dog = 0
# zero_dog = 0

# predict = clf.predict(x_test)

# for line in predict:
#     if count < 5000 and line == 1:
#         um_cat += 1
#     elif count < 5000 and line == 0:
#         zero_cat += 1
#     elif count >= 5000 and line == 1:
#         um_dog += 1
#     elif count >= 5000 and line == 0:
#         zero_dog += 1
    
#     print(count, line )
#     count += 1

# print(f'cat fail : {um_cat}')
# print(f'cat success: {zero_cat}')
# print(f'dog fail: {zero_dog}')
# print(f'dog success: {um_dog}')

# print(clf.score(x_test, y_train))


#--------------------------------------------------------------------------------


# # X, y = make_classification(n_samples=100, random_state=1)
# # X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y,
# # ...                                                     random_state=1)

# # labels = h5py.File('labels.h5', 'r')
# # hdf = h5py.File("SOBEL_train.h5", 'r')
# hdf_test = h5py.File("SOBEL_test.h5", 'r')

# # x_train = np.array(hdf['dataset_LBP_train'])
# # y_train = np.array(labels['label'])
# # x_test = np.array(hdf['dataset_LBP_test'])
# print(hdf_test.keys())
# hdf_test.close()
# # hdf.close()
# # labels.close()

# # clf = MLPClassifier(activation = 'tanh', alpha=0.001,
# #                     solver = 'adm',  random_state=1,
# #                     verbose = True, max_iter=10).fit(x_train, y_train)



# # MLPClassifier(hidden_layer_sizes=100, activation='relu', *, 
# #               solver='adam', alpha=0.0001, batch_size='auto', 
# #               learning_rate='constant', learning_rate_init=0.001, 
# #               power_t=0.5, max_iter=200, shuffle=True, random_state=None, 
# #               tol=0.0001, verbose=False, warm_start=False, momentum=0.9,
# #               nesterovs_momentum=True, early_stopping=False, 
# #               validation_fraction=0.1, beta_1=0.9, beta_2=0.999, 
# #               epsilon=1e-08, n_iter_no_change=10, max_fun=15000)[source]




# # clf.predict_proba(X_test[:1])
# # clf.predict(X_test[:5, :])
# # clf.score(X_test, y_test)
# Out:
# [LibSVM]foi
# 0 0
# 1 1
# 2 1
# 3 1
# 4 0
# 5 0
# 6 0
# 7 1
# 8 0
# 9 0
# 10 0
# 11 0
# 12 1
# 13 0
# 14 0
# 15 0
# 16 0
# 17 0
# 18 0
# 19 1
# 20 0
# 21 0
# 22 1
# 23 0
# 24 1
# 25 0
# 26 1
# 27 0
# 28 0
# 29 1
# 30 0
# 31 0
# 32 0
# 33 0
# 34 1
# 35 0
# 36 0
# 37 0
# 38 1
# 39 0
# 40 0
# 41 0
# 42 1
# 43 0
# 44 0
# 45 0
# 46 0
# 47 0
# 48 1
# 49 0
# 50 0
# 51 0
# 52 0
# 53 1
# 54 0
# 55 0
# 56 0
# 57 0
# 58 0
# 59 1
# 60 1
# 61 1
# 62 0
# 63 0
# 64 0
# 65 1
# 66 0
# 67 1
# 68 0
# 69 0
# 70 0
# 71 0
# 72 0
# 73 0
# 74 1
# 75 1
# 76 0
# 77 0
# 78 1
# 79 0
# 80 1
# 81 0
# 82 1
# 83 0
# 84 0
# 85 0
# 86 0
# 87 0
# 88 1
# 89 1
# 90 0
# 91 0
# 92 1
# 93 0
# 94 1
# 95 0
# 96 0
# 97 1
# 98 0
# 99 0
# 100 0
# 101 0
# 102 0
# 103 0
# 104 0
# 105 0
# 106 1
# 107 0
# 108 0
# 109 0
# 110 0
# 111 0
# 112 0
# 113 0
# 114 0
# 115 1
# 116 0
# 117 0
# 118 0
# 119 1
# 120 0
# 121 1
# 122 0
# 123 0
# 124 0
# 125 0
# 126 0
# 127 1
# 128 0
# 129 0
# 130 0
# 131 0
# 132 0
# 133 0
# 134 0
# 135 0
# 136 1
# ...
